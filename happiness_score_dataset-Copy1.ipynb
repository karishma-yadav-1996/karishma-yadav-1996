# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy(GDP per Capita)   Family  \
# 0              7.587         0.03411                  1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# We have 158 rows and 12 columns in dataset.

# %%
df.dtypes
# Out:
# Country                          object
# Region                           object
# Happiness Rank                    int64
# Happiness Score                 float64
# Standard Error                  float64
# Economy(GDP per Capita)         float64
# Family                          float64
# Health (Life Expectancy)        float64
# Freedom                         float64
# Trust(Government Corruption)    float64
# Generosity                      float64
# Dystopia_Residual               float64
# dtype: object

# %% [markdown]
# We have float,int and object types of values which are independent variable
# and the dystopia_residual is our target variable in this dataset.

# %%
df.keys()
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy(GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust(Government Corruption)',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy(GDP per Capita)      Family  Health (Life Expectancy)  \
# count               158.000000  158.000000                158.000000
# mean                  0.846137    0.991046                  0.630259
# std                   0.403121    0.272369                  0.247078
# min                   0.000000    0.000000                  0.000000
# 25%                   0.545808    0.856822                  0.439185
# ...

# %% [markdown]
# High standard deviation present in Happiness Rank variable means data is sepreated.
# Family,Health,Generosity and dysotipa_residual has mean grater than median,it means outliers are presents.

# %%
df.isnull().sum()
# Out:
# Country                         0
# Region                          0
# Happiness Rank                  0
# Happiness Score                 0
# Standard Error                  0
# Economy(GDP per Capita)         0
# Family                          0
# Health (Life Expectancy)        0
# Freedom                         0
# Trust(Government Corruption)    0
# Generosity                      0
# Dystopia_Residual               0
# dtype: int64

# %% [markdown]
# There are no null values in this dataset.

# %%
plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# There are no null values in the datasets.

# %%
df.Dystopia_Residual.unique()
# Out:
# array([2.51738, 2.70201, 2.49204, 2.46531, 2.45176, 2.61955, 2.4657 ,
#        2.37119, 2.26425, 2.26646, 3.08854, 3.17728, 2.5332 , 3.60214,
#        2.51011, 3.26001, 1.96961, 1.9757 , 2.41484, 2.24743, 1.96994,
#        2.47489, 3.19131, 1.88501, 2.84848, 2.11569, 2.67585, 1.55674,
#        2.21126, 2.836  , 2.67782, 2.32142, 2.85737, 2.31945, 2.43872,
#        2.12367, 1.6488 , 2.32323, 1.87634, 2.79094, 2.26882, 3.035  ,
#        2.74255, 2.23741, 2.24639, 1.68435, 2.21978, 2.53942, 1.73797,
#        2.02518, 2.82334, 3.10712, 2.18896, 2.24729, 1.61583, 2.44649,
#        2.32407, 2.5945 , 2.1309 , 1.86565, 1.88541, 2.75414, 2.09066,
#        2.27394, 2.32038, 1.59888, 1.88931, 2.43209, 2.76579, 1.86984,
#        1.76145, 0.65429, 1.58782, 1.86399, 2.20173, 2.08528, 2.2327 ,
#        2.89319, 1.63794, 2.00073, 3.10709, 1.87996, 2.10017, 1.8604 ,
#        2.6343 , 1.93129, 2.025  , 1.26462, 1.62215, 1.7536 , 2.11032,
# ...

# %%
df.Dystopia_Residual.value_counts()
# Out:
# 2.77729    1
# 2.67585    1
# 1.87996    1
# 1.59927    1
# 3.10712    1
#           ..
# 1.94296    1
# 2.02500    1
# 1.42766    1
# 2.82334    1
# 2.10017    1
# Name: Dystopia_Residual, Length: 158, dtype: int64

# %% [markdown]
# Each column has atleast one value present in this dataset.

# %% [markdown]
#  # EDA

# %% [markdown]
# Univariate analysis

# %%
sns.countplot(df['Dystopia_Residual']);

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %% [markdown]
# skewness is present in this plot.

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %% [markdown]
# skewness is present in given plot.

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %% [markdown]
# also skewness is present in this plot.

# %%
sns.displot(df['Trust(Government Corruption)'])

# %% [markdown]
# skewness is present.

# %%
sns.displot(df['Health (Life Expectancy)'])

# %% [markdown]
# skewness is present.

# %%
sns.displot(df['Economy(GDP per Capita)'])

# %%
sns.boxplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %% [markdown]
# Their is no outlier present in above plot.

# %%
sns.boxplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family'>

# %% [markdown]
# In this plot outliers are present.

# %%
sns.boxplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom'>

# %% [markdown]
# Their are no outliers present.

# %%
sns.boxplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error'>

# %% [markdown]
# In this plot outliers are present.

# %%
sns.boxplot(df['Economy(GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy(GDP per Capita)'>

# %% [markdown]
# Their are no outliers present.

# %%
sns.boxplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %% [markdown]
# This plot contains outliers.

# %%
sns.boxplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)'>

# %% [markdown]
# no outliers present.

# %%
sns.boxplot(df['Trust(Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust(Government Corruption)'>

# %% [markdown]
# outliers are present.

# %% [markdown]
# # Bivariate analysis

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Happiness Score and Family')
sns.scatterplot(df['Happiness Score'], df['Family'],hue=df['Dystopia_Residual']);

# %% [markdown]
# ploting the relationships between Happiness score and Family.

# %%
sns.pairplot(df,hue="Dystopia_Residual")

# %%
cor=df.corr()

# %%
cor
# Out:
#                               Happiness Rank  Happiness Score  Standard Error  \
# Happiness Rank                      1.000000        -0.992105        0.158516
# Happiness Score                    -0.992105         1.000000       -0.177254
# Standard Error                      0.158516        -0.177254        1.000000
# Economy(GDP per Capita)            -0.785267         0.780966       -0.217651
# Family                             -0.733644         0.740605       -0.120728
# Health (Life Expectancy)           -0.735613         0.724200       -0.310287
# Freedom                            -0.556886         0.568211       -0.129773
# Trust(Government Corruption)       -0.372315         0.395199       -0.178325
# Generosity                         -0.160142         0.180319       -0.088439
# Dystopia_Residual                  -0.521999         0.530474        0.083981
#
#                               Economy(GDP per Capita)    Family  \
# ...

# %%
sns.heatmap(cor,annot=True,linewidth=0.5,linecolor='green')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# This plot shows the correlation between the variables on the axis.correlation ranges from -1 to +1.
# In this plot larger number and darker the color the higher corrlation between the two variables.

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Country"]=LE.fit_transform(df["Country"])

# %%
df["Country"].unique()
# Out:
# array([135,  58,  37, 105,  24,  45,  99, 134, 100,   6,  64,  33,   7,
#         91, 150,  18,  82,  63,  12, 148, 149, 106, 153, 123, 109,  49,
#         27, 115,  46,   4,  36, 151,  29, 140, 119, 129,  88, 137,  73,
#        132, 142,  42,  52, 152, 124,  68, 128,  40,   9,  65,  15,  92,
#        110,  70, 125,  81, 101, 111,  11, 113,  86,  34,  80, 117,  67,
#        104,  35,   2,  72, 145,  90,  56,  43,  60, 154, 144,  74, 103,
#         14,   8, 107,  69,  94,  28, 156, 116, 121, 114,  76, 112, 126,
#         95,  83,  96,   1,  16,  78,  39,  75,  93, 133,  51,  77,  57,
#         55, 138, 143, 108,  10,  61, 147,  62, 127,  50, 157,  79,  59,
#        131,  54,  32,  98,  44, 122,  89,  71,  38,   5,  17,  97,  48,
#         85, 130,  23,  19,  41, 155,   3,  87,  31,  30, 146, 120,  47,
#        102,  22, 139,  84,  25,  26,  53,  66,  20,   0, 118,  13, 136,
#         21, 141])

# %%
df["Region"]=LE.fit_transform(df["Region"])

# %%
df["Region"].unique()
# Out:
# array([9, 5, 0, 4, 3, 6, 1, 2, 8, 7])

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy(GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
corr_matrix=df.corr()
corr_matrix["Dystopia_Residual"].sort_values(ascending=False)
# Out:
# Dystopia_Residual               1.000000
# Happiness Score                 0.530474
# Family                          0.148117
# Standard Error                  0.083981
# Freedom                         0.062783
# Economy(GDP per Capita)         0.040059
# Health (Life Expectancy)        0.018979
# Country                        -0.019778
# Trust(Government Corruption)   -0.033105
# Region                         -0.057276
# Generosity                     -0.101301
# Happiness Rank                 -0.521999
# Name: Dystopia_Residual, dtype: float64

# %% [markdown]
# Their are identify the corrlation of independent variable with target variable "Dystopia_Residual".

# %% [markdown]
# # Outlier removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

new_df=df[(z<4).all(axis=1)]

# %%
new_df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy(GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
new_df.shape
# Out:
# (156, 12)

# %%
df.shape
# Out:
# (158, 12)

# %%
(2/158)*100
# Out:
# 1.2658227848101267

# %% [markdown]
# # checking outliers

# %%
new_df.plot(kind='box',subplots=True,layout=(2,7))
# Out:
# Country                            AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# Region                          AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# Happiness Rank                  AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# Happiness Score                 AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# Standard Error                  AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# Economy(GDP per Capita)         AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# Family                          AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# Health (Life Expectancy)              AxesSubplot(0.125,0.125;0.0945122x0.343182)
# Freedom                            AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# Trust(Government Corruption)       AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# Generosity                         AxesSubplot(0.465244,0.125;0.0945122x0.343182)
# ...

# %% [markdown]
# # Skewness

# %%
new_df.skew()
# Out:
# Country                         0.002641
# Region                         -0.121958
# Happiness Rank                  0.007279
# Happiness Score                 0.090688
# Standard Error                  1.532729
# Economy(GDP per Capita)        -0.332441
# Family                         -1.017152
# Health (Life Expectancy)       -0.709519
# Freedom                        -0.401505
# Trust(Government Corruption)    1.386524
# Generosity                      0.632156
# Dystopia_Residual              -0.245725
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error

# %%
from scipy.stats import skew

# %%
for col in new_df:
    print(col)
    print(skew(new_df[col]))
    
    plt.figure()
    sns.displot(new_df[col])
    plt.show()
# Out:
# Country
# 0.002615278080514924
# Region
# -0.12078241799567155
# Happiness Rank
# 0.007208718297494264
# Happiness Score
# 0.08981333430138723
# Standard Error
# 1.5179516729498908
# Economy(GDP per Capita)
# -0.329236359137139
# Family
# -1.0073452362787272
# Health (Life Expectancy)
# -0.7026783913063752
# Freedom
# -0.39763413003006876
# Trust(Government Corruption)
# 1.3731557820812665
# Generosity
# 0.6260610969031846
# Dystopia_Residual
# -0.2433558427520191

# %%
new_df["Trust(Government Corruption)"]=np.sqrt(new_df["Trust(Government Corruption)"])
skew(new_df["Trust(Government Corruption)"])
# Out:
# -0.4222235242731016

# %%
new_df["Standard Error"]=np.sqrt(new_df["Standard Error"])
skew(new_df["Standard Error"])
# Out:
# 0.46113986129744894

# %%
new_df["Generosity"]=np.sqrt(new_df["Generosity"])
skew(new_df["Generosity"])
# Out:
# -0.30399985433114335

# %%
new_df.skew()
# Out:
# Country                         0.002641
# Region                         -0.121958
# Happiness Rank                  0.007279
# Happiness Score                 0.090688
# Standard Error                  0.465629
# Economy(GDP per Capita)        -0.332441
# Family                         -1.017152
# Health (Life Expectancy)       -2.668739
# Freedom                        -0.401505
# Trust(Government Corruption)   -0.426334
# Generosity                     -0.306959
# Dystopia_Residual              -0.245725
# dtype: float64

# %% [markdown]
# Skewness has been removed in this dataset.

# %%
x=new_df.iloc[ : ,0:-1]
x
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy(GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
y=new_df.iloc[ : ,-1]
y
# Out:
# 0      2.51738
# 1      2.70201
# 2      2.49204
# 3      2.46531
# 4      2.45176
#         ...
# 153    0.67042
# 154    1.63328
# 155    0.32858
# 156    1.83302
# 157    1.56726
# Name: Dystopia_Residual, Length: 156, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=45)

# %%
x_train.shape
# Out:
# (121, 11)

# %%
y_train.shape
# Out:
# (121,)

# %%
x_test
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 40       142       3              41            6.168         0.10895
# 38        73       4              39            6.295         0.04456
# 3        105       9               4            7.522         0.03880
# 65       104       9              66            5.695         0.05635
# 44       124       1              45            5.995         0.04267
# 62        80       4              63            5.754         0.07832
# 90       126       8              91            5.057         0.06161
# 137       87       8             138            3.995         0.05602
# 70        90       8              71            5.477         0.07197
# 147       25       8             148            3.678         0.06112
# 10        64       4              11            7.278         0.03470
# ...

# %%
y_test
# Out:
# 0      2.51738
# 40     2.26882
# 38     1.87634
# 3      2.46531
# 65     1.59888
# 44     2.24639
# 62     2.09066
# 90     2.11032
# 137    1.79293
# 70     1.76145
# 147    2.72230
# 10     3.08854
# 77     2.89319
# 124    1.78555
# 148    1.94296
# 35     2.12367
# 139    1.95812
# 131    0.67108
# 150    1.41723
# 135    1.92313
# 116    2.27513
# 92     1.73933
# 157    1.56726
# 91     2.45373
# 126    1.75873
# 98     1.73799
# 72     1.58782
# 4      2.45176
# 132    1.95071
# 28     2.21126
# 95     2.06367
# 34     2.43872
# 67     2.43209
# 100    2.48676
# 138    1.68135
# Name: Dystopia_Residual, dtype: float64

# %%
scaling=StandardScaler()

# %%
x_train=scaling.fit_transform(x_train)

# %%
x_test=scaling.transform(x_test)

# %%
x_train
# Out:
# array([[-0.65445891, -1.28254145,  1.17613537, ..., -0.14790038,
#          1.94951787, -1.48379556],
#        [-0.63288726,  1.36458035, -1.13861088, ...,  1.19091167,
#          0.59915392,  0.39725556],
#        [ 0.22997875,  1.03369013,  1.04259232, ..., -1.19492827,
#          0.24026898, -0.12672012],
#        ...,
#        [-1.06432027, -0.620761  , -0.98281065, ...,  0.67774309,
#         -0.77045649, -0.41708929],
#        [-0.87017542,  1.03369013,  1.08710667, ...,  0.20422641,
#          1.11201048, -0.44264908],
#        [-1.28003677, -1.28254145,  1.26516407, ..., -0.78783972,
#         -1.11836686, -0.9548407 ]])

# %%
x_test
# Out:
# array([[ 1.22227467e+00,  1.36458035e+00, -1.69504027e+00,
#          1.92178435e+00, -8.10791985e-01,  1.36160126e+00,
#          1.33953297e+00,  1.24823325e+00,  1.51632627e+00,
#          2.24820645e+00,  5.18747541e-01],
#        [ 1.37327622e+00, -6.20761002e-01, -8.04753246e-01,
#          6.57411458e-01,  4.22662746e+00,  8.97371575e-01,
#          6.94218384e-01, -1.40474994e-01,  8.32635317e-01,
#         -1.09641771e+00,  6.98495929e-01],
#        [-1.15167654e-01, -2.89870776e-01, -8.49267597e-01,
#          7.70572386e-01, -1.07410997e-01,  1.75803652e+00,
#          6.25787122e-01,  3.27629387e-01,  8.07972990e-01,
#          9.07588575e-01, -5.97418581e-01],
#        [ 5.75125158e-01,  1.36458035e+00, -1.62826874e+00,
#          1.86386734e+00, -4.95111905e-01,  1.51868223e+00,
#          1.26736909e+00,  1.00918494e+00,  1.54297440e+00,
#          1.79980503e+00,  9.35421898e-01],
#        [ 5.53553507e-01,  1.36458035e+00, -2.48323859e-01,
# ...

# %%
scaling.fit_transform(new_df)
# Out:
# array([[ 1.23277306,  1.29177841, -1.71214854, ...,  2.29959811,
#          0.52907751,  0.75216856],
#        [-0.44595611,  1.29177841, -1.69027342, ..., -0.02036376,
#          1.70254496,  1.08643347],
#        [-0.90379133,  1.29177841, -1.6683983 , ...,  2.8313064 ,
#          0.90428094,  0.70629155],
#        ...,
#        [ 1.25457473, -0.37641225,  1.67849451, ...,  0.3764795 ,
#          2.00104238, -3.2105624 ],
#        [-1.25261817,  0.95814028,  1.70036963, ..., -0.36069374,
#         -0.30787594, -0.48683663],
#        [ 1.36358312,  0.95814028,  1.72224475, ..., -0.30493063,
#         -0.5640673 , -0.967984  ]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 1.30875273e-06,  1.38235836e-05,  4.71409819e-06,  1.00015019e+00,
#         1.62303959e-03, -1.00002540e+00, -9.99982523e-01, -9.99732428e-01,
#        -9.99819094e-01, -1.00004573e+00, -1.00012898e+00])

# %%
lm.intercept_
# Out:
# -0.0016255830938343152

# %%
lm.score(x_train,y_train)
# Out:
# 0.9999997984002843

# %%
new_data=np.array([0.234,0.456,0.765,0.876,0.985,3.567,7.659,4.0900,1.0,269.0,17.5,356.98]).reshape(2,6)
new_data
# Out:
# array([[2.3400e-01, 4.5600e-01, 7.6500e-01, 8.7600e-01, 9.8500e-01,
#         3.5670e+00],
#        [7.6590e+00, 4.0900e+00, 1.0000e+00, 2.6900e+02, 1.7500e+01,
#         3.5698e+02]])

# %%
new_data.shape
# Out:
# (2, 6)

# %%
for i in range(200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)
    from sklearn.tree import DecisionTreeRegressor
    DTR=DecisionTreeRegressor()
    DTR.fit(x_train,y_train)
    pred=DTR.predict(x_test)
    print("predicted result price:",pred)
    print("actual price:",y_test)
# Out:
# predicted result price: [3.10709 2.04384 2.75414 2.5945  2.02518 1.88541 2.37119 1.95335 1.87634
#  1.46494 1.46494 1.87996 2.79832 1.6944  2.80791 2.51738 2.89319 2.51738
#  2.47489 2.5945  2.82334 1.44395 0.67042 1.46181 1.6944  1.88931 2.025
#  2.85737 2.20857 2.21978 1.59927 1.92313 1.86984 2.75414 1.99172 1.68435
#  1.6944  1.73933 1.46494 1.59927 2.5945  1.55674 2.20857 1.21305 1.68435
#  1.88501 2.04384 2.04384 1.95812 1.86399 1.88501 2.09066]
# actual price: 118    2.24173
# 76     2.23270
# 51     3.10712
# 31     2.32142
# 35     2.12367
# 40     2.26882
# 14     2.51011
# 110    1.57140
# 53     2.24729
# 148    1.94296
# 152    1.95210
# 79     2.00073
# 93     3.05137
# 91     2.45373
# 90     2.11032
# 5      2.61955
# 124    1.78555
# 16     1.96961
# 19     2.24743
# 29     2.83600
# 56     2.32407
# 145    1.38079
# 144    0.98195
# 100    2.48676
# 94     1.89894
# 70     1.76145
# 95     2.06367
# 42     2.74255
# 123    2.11773
# 44     2.24639
# 106    2.12466
# ...

# %%
print("error:")

print('Mean squared error:',mean_squared_error(y_test,pred))


print('Mean absolute error:',mean_absolute_error(y_test,pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean squared error: 0.19432479332307692
# Mean absolute error: 0.34825115384615385
# Root Mean Squared Error: 0.4408228593472404

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# -0.0059793759707231775

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)

# %%
ls.coef_

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
#enr=ElasticNet()
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_

# %%
from sklearn.svm import SVR

svr=SVR()
svr=SVR(kernel="linear")
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

svr=SVR(kernel="poly")
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

svr=SVR(kernel="rbf")
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
from sklearn.svm import SVR

kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))

# %%
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor(n_estimators=10,random_state=0)
RFR.fit(x_train,y_train)
pred=RFR.predict(x_test)
msr=mean_squared_error(y_test,pred)
print(msr)

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(DTR,x,y,cv=5).mean())

# %%
print(cross_val_score(svr,x,y,cv=5).mean())

# %%
print(cross_val_score(RFR,x,y,cv=5).mean())

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'max_depth' : np.arange(2,10),
           'criterion' : ['mse', 'friedman_mse', 'mae', 'poisson']}

# %%
GCV=GridSearchCV(DecisionTreeRegressor(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)

# %%
GCV.best_params_

# %%
Final_mod=DecisionTreeRegressor(criterion='mse', max_depth=2)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
msr=mean_squared_error(y_test,pred)
print(msr)

# %% [markdown]
# # saving the model

# %%
import joblib
joblib.dump(Final_mod, "FinalModel.pkl")
