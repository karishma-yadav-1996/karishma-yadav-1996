# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Census Income.csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# we have 32560 rows and 15 columns in this dataset.

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# we have int types and object types of values which are independent variable and the Income is our target variable in this dataset.

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# In this dataset 14 features and 1 target variable.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# There are no missing values in this dataset.

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# There are 32560 samples in this dataset
# There are both categorical and numerical columns in the dataset.
# fnlwgt appears to be a highly dispersive. In fact, it is a weight on the Current Population Survey (CPS) files. We will not incorporate fnlwgt in set of predictor variables.

# %%
df["Income"].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %% [markdown]
# Income in US falls in the income category of either greater than 50K Dollars or less equal to 50K Dollars

# %%
df["Income"].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %% [markdown]
# <=50k column has most values as compared to >50k column. <=50k column has 24719 values. >50k column has 7841 values.

# %% [markdown]
# # EDA

# %%
sns.countplot(df["Income"]);

# %% [markdown]
# Target class is imbalance.

# %%
sns.boxplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# Outliers are present in this column.

# %%
sns.boxplot(df["Fnlwgt"])
# Out:
# <AxesSubplot:xlabel='Fnlwgt'>

# %% [markdown]
# outliers are present in this plot.

# %%
sns.boxplot(df["Education_num"])
# Out:
# <AxesSubplot:xlabel='Education_num'>

# %% [markdown]
# outliers are present in the left side of the whiskers.

# %%
sns.boxplot(df["Capital_gain"])
# Out:
# <AxesSubplot:xlabel='Capital_gain'>

# %% [markdown]
# outliers are present in this plot.

# %%
sns.boxplot(df["Capital_loss"])
# Out:
# <AxesSubplot:xlabel='Capital_loss'>

# %% [markdown]
# outliers are present.

# %%
sns.boxplot(df["Hours_per_week"])
# Out:
# <AxesSubplot:xlabel='Hours_per_week'>

# %% [markdown]
# outliers are present in this plot.

# %%
sns.distplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# Data is normaly distributed, this data is Right skewed.

# %%
sns.distplot(df["Hours_per_week"])
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed.

# %%
sns.distplot(df["Capital_loss"])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed.

# %%
sns.distplot(df["Capital_gain"])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %% [markdown]
# Data is normaly distributed in this plot.

# %%
sns.distplot(df["Education_num"])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Density'>

# %% [markdown]
# Data is normaly distributed in this plot.

# %%
sns.distplot(df["Fnlwgt"])
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Density'>

# %% [markdown]
# Data is normaly distributed in this plot.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10,5)
sns.violinplot(df.dropna(subset = ['Income']).Income)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-86cd69dedc0a> in <module>
#       1 fig, ax = plt.subplots()
#       2 fig.set_size_inches(10,5)
# ----> 3 sns.violinplot(df.dropna(subset = ['Income']).Income)
#
# E:\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# E:\anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385 ):
#    2386
# -> 2387     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
plt.figure(figsize=(20,20))
sns.set_style('whitegrid')
sns.pointplot(x='Income',y='Age',data=df, hue='Hours_per_week',join=False)
plt.xticks(np.linspace(1,2,5))
plt.xlabel('Age',{'fontsize' : 'large'})
plt.ylabel('Income',{'fontsize':'large'})
plt.title("Hours_per_week Income in Each Age",{'fontsize':20})

# %% [markdown]
# In this chart, we can see the Income change between the Age.

# %% [markdown]
# # Bivariate analysis

# %%
plt.scatter(df["Age"],df["Income"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Comparision between Age and Income")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present in this plot.

# %%
plt.scatter(df["Fnlwgt"],df["Education_num"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Comparision between Fnlwgt and Education_num")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present in this plot.

# %%
plt.scatter(df["Capital_gain"],df["Capital_loss"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Comparision between Capital_gain and Capital_loss")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present in this plot.

# %%
plt.scatter(df["Income"],df["Hours_per_week"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Comparision between Income and Hours_per_week")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present in this plot.

# %%
sns.jointplot(data=df,x='Age',y='Fnlwgt',kind='reg')

# %% [markdown]
# using jointplot to find the best line or curve that fits the plots.In this plot Age and Fnlwgt are two variables in ploting.

# %%
sns.jointplot(data=df,x='Capital_gain',y='Capital_loss',kind='reg')

# %% [markdown]
# using jointplot to find the best line or curve that fits the plots.In this plot Capital_gain and Capital_loss are two variables in ploting.

# %%
sns.jointplot(data=df,x='Age',y='Hours_per_week',kind='reg')

# %% [markdown]
# using jointplot to find the best line or curve that fits the plots.In this plot Age and Hours_per_week are two variables in ploting.

# %%
sns.pairplot(df,hue="Income")

# %% [markdown]
# We can check the corelation between dependent and independent features using dataframe.corr() function. This plot pairwise relationships in a dataset.

# %% [markdown]
# # checking correlation

# %%
cor=df.corr()
cor
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %% [markdown]
# This column is checking correlation between different different columns.

# %%
plt.figure(figsize=[20,12])
sns.heatmap(cor,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# I am using seaborn heatmap to plot the correlated matrix and plot the corr value in the heatmap graph.
# Dark shades are very bad correlation between columns.if there is any relationship amongst the numerical variables and the response, income, is to create a correlation plot. However, the response is a factor variable with levels 1 and 2 and is unable to be directly added to the correlation plot. Therefore, I made the income variable into a binary variable with levels 0 and 1 to overcome this problem.
# We can see that the numerical variables do not seem to be strongly correlated with each other. However, we see the final weight variable does not appear to have an association with the response either.

# %% [markdown]
# # correlation metrix

# %%
corr_matrix=df.corr()
corr_matrix["Income"].sort_values(ascending=False)
# Out:
# Income            1.000000
# Education_num     0.335182
# Age               0.234039
# Hours_per_week    0.229690
# Capital_gain      0.223333
# Sex               0.215995
# Capital_loss      0.150523
# Education         0.079311
# Occupation        0.075448
# Race              0.071853
# Workclass         0.051645
# Native_country    0.015845
# Fnlwgt           -0.009481
# Marital_status   -0.199295
# Relationship     -0.250924
# Name: Income, dtype: float64

# %% [markdown]
# I am finding the correlation value of each column. Their are identify the corrlation of independent variable with target variable "Income".

# %% [markdown]
# # Label encoder

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
df["Income"]=LE.fit_transform(df["Income"])
df["Income"].unique()
# Out:
# array([0, 1])

# %%
df["Workclass"]=LE.fit_transform(df["Workclass"])
df["Workclass"].unique()
# Out:
# array([6, 4, 7, 1, 2, 0, 5, 8, 3])

# %%
df["Education"]=LE.fit_transform(df["Education"])
df["Education"].unique()
# Out:
# array([ 9, 11,  1, 12,  6, 15,  7,  8,  5, 10, 14,  4,  0,  3, 13,  2])

# %%
df["Marital_status"]=LE.fit_transform(df["Marital_status"])
df["Marital_status"].unique()
# Out:
# array([2, 0, 3, 4, 5, 1, 6])

# %%
df["Occupation"]=LE.fit_transform(df["Occupation"])
df["Occupation"].unique()
# Out:
# array([ 4,  6, 10,  8,  1, 12,  3, 14,  5,  7, 13,  0, 11,  2,  9])

# %%
df["Relationship"]=LE.fit_transform(df["Relationship"])
df["Relationship"].unique()
# Out:
# array([0, 1, 5, 3, 4, 2])

# %%
df["Race"]=LE.fit_transform(df["Race"])
df["Race"].unique()
# Out:
# array([4, 2, 1, 0, 3])

# %%
df["Sex"]=LE.fit_transform(df["Sex"])
df["Sex"].unique()
# Out:
# array([1, 0])

# %%
df["Native_country"]=LE.fit_transform(df["Native_country"])
df["Native_country"].unique()
# Out:
# array([39,  5, 23, 19,  0, 26, 35, 33, 16,  9,  2, 11, 20, 30, 22, 31,  4,
#         1, 37,  7, 25, 36, 14, 32,  6,  8, 10, 13,  3, 24, 41, 29, 28, 34,
#        38, 12, 27, 40, 17, 21, 18, 15])

# %% [markdown]
# There are 9 columns is object types variable . Using Label encoder these 9 column is converting into int type.

# %% [markdown]
# # outlier removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

new_df=df[(z<5).all(axis=1)]

# %%
new_df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
new_df.shape
# Out:
# (32103, 15)

# %%
df.shape
# Out:
# (32560, 15)

# %%
(457/32560)*100
# Out:
# 1.4035626535626535

# %% [markdown]
# outliers has been removed in this dataset.

# %% [markdown]
# # skewness

# %%
x=df.drop("Income",axis=1)
y=df["Income"]

# %%
x.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# Native_country    -3.658235
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
new_df=power_transform(x)

new_df=pd.DataFrame(new_df,columns=x.columns)

# %%
new_df.skew()
# Out:
# Age              -0.013897
# Workclass         0.061629
# Fnlwgt            0.016914
# Education        -0.309431
# Education_num     0.023885
# Marital_status   -0.114201
# Occupation       -0.187152
# Relationship      0.122917
# Race             -2.010817
# Sex              -0.719244
# Capital_gain      3.016951
# Capital_loss      4.299511
# Hours_per_week    0.229556
# Native_country   -2.725467
# dtype: float64

# %% [markdown]
# skewness has been removed.

# %% [markdown]
# # Handling class imbalance problem by oversampling the minority class

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x_over,y_over=SM.fit_resample(x,y)

# %%
y_over.value_counts()
# Out:
# 1    24719
# 0    24719
# Name: Income, dtype: int64

# %% [markdown]
# # standard scaler

# %%
from sklearn.preprocessing import StandardScaler

scaling=StandardScaler()
scaledX=scaling.fit_transform(df)

# %%
scaledX
# Out:
# array([[ 0.83709708,  1.46388339, -1.0087417 , ..., -2.22212013,
#          0.29157343, -0.5632099 ],
#        [-0.04264043,  0.09012148,  0.24504633, ..., -0.03542999,
#          0.29157343, -0.5632099 ],
#        [ 1.05703146,  0.09012148,  0.42576955, ..., -0.03542999,
#          0.29157343, -0.5632099 ],
#        ...,
#        [ 1.42358875,  0.09012148, -0.3588108 , ..., -0.03542999,
#          0.29157343, -0.5632099 ],
#        [-1.21562378,  0.09012148,  0.11092744, ..., -1.65520046,
#          0.29157343, -0.5632099 ],
#        [ 0.98372   ,  0.77700244,  0.92986178, ..., -0.03542999,
#          0.29157343,  1.77553698]])

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

testpca=PCA()
Y=testpca.fit(scaledX)

# %%
Y.explained_variance_ratio_
# Out:
# array([0.16009723, 0.0964074 , 0.08466437, 0.07648492, 0.07154371,
#        0.06869844, 0.0656484 , 0.06277153, 0.05712505, 0.05632321,
#        0.05095662, 0.04593343, 0.04329502, 0.03473625, 0.02531443])

# %%
var_cumu=np.cumsum(Y.explained_variance_ratio_)*100
var_cumu
# Out:
# array([ 16.00972286,  25.65046315,  34.11689993,  41.76539239,
#         48.91976294,  55.78960665,  62.35444654,  68.63159918,
#         74.34410403,  79.97642503,  85.07208694,  89.66542948,
#         93.99493139,  97.46855687, 100.        ])

# %% [markdown]
#  # creating final dataset with 12 columns

# %%
FinalPCA=PCA(n_components=12)
FinalData=FinalPCA.fit_transform(scaledX)

# %%
FinalData2=pd.DataFrame(FinalData)
FinalData2
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.505231 -0.213030  0.272255 -0.983892 -0.860677 -0.002681 -0.453416
# 1      0.554889 -0.742675  0.343895 -0.642631 -0.123040  0.170362 -0.471048
# 2     -0.084547 -2.803941  0.347059  1.083948 -0.732178  0.075054 -0.031038
# 3     -2.006328  0.925007 -1.600155  4.214093 -0.428020 -0.580430 -0.485290
# 4     -1.340735  2.119320  0.216358 -0.102657 -0.193268  0.213997  0.350718
# ...         ...       ...       ...       ...       ...       ...       ...
# 32555 -1.645075  1.135497 -1.290417 -0.188732 -1.020480  0.255542  1.128880
# 32556  1.512756 -0.360798  0.305860 -0.367687  0.068662  0.162565  0.053471
# 32557 -2.015119  0.762209  0.908621 -0.355675 -0.532703  0.160195  0.286105
# 32558 -1.819039 -0.039641  0.152733 -0.804695  1.144884  0.295596  0.139101
# 32559 -0.148929  1.522768  0.732976  0.893586 -1.311386  1.668578  1.951831
#
#              7         8         9         10        11
# ...

# %%
k=np.argmax(var_cumu>90)
print("Number of components explaining 90% variance: ",k)
# Out:
# Number of components explaining 90% variance:  12

# %%
plt.ylabel('Cumulative Explained variance')
plt.xlabel('Principal components')
plt.axvline(x=k, color="k", linestyle="--")
plt.axhline(y=9, color="r",  linestyle="--")

plt.plot(var_cumu)
plt.show()

# %% [markdown]
# PCA gives new indicators which are linear combinations of the original ones, thus the new indicators combines similar old indicators through their shared properties, you are going to redefine these new indicators according to your understanding of the potential shared properties.

# %% [markdown]
# # finding best random_state

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import LinearSVC

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=12)

# %% [markdown]
# # Logistic regression

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
pred=lg.predict(x_test)
lg_accu=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.7849232201023731
# [[7668  443]
#  [1868  766]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87      8111
#            1       0.63      0.29      0.40      2634
#
#     accuracy                           0.78     10745
#    macro avg       0.72      0.62      0.63     10745
# weighted avg       0.76      0.78      0.75     10745

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn_pred=knn.predict(x_test)
knn_accu=accuracy_score(y_test,pred)

print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.7849232201023731
# [[7668  443]
#  [1868  766]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87      8111
#            1       0.63      0.29      0.40      2634
#
#     accuracy                           0.78     10745
#    macro avg       0.72      0.62      0.63     10745
# weighted avg       0.76      0.78      0.75     10745

# %% [markdown]
# # RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
rf_accu=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.8538855281526291
# [[7520  591]
#  [ 979 1655]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      8111
#            1       0.74      0.63      0.68      2634
#
#     accuracy                           0.85     10745
#    macro avg       0.81      0.78      0.79     10745
# weighted avg       0.85      0.85      0.85     10745

# %% [markdown]
# # SVC

# %%
svc=SVC()
svc.fit(x_train,y_train)
pred=svc.predict(x_test)
svc_accu=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.7879944160074454
# [[8101   10]
#  [2268  366]]
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      8111
#            1       0.97      0.14      0.24      2634
#
#     accuracy                           0.79     10745
#    macro avg       0.88      0.57      0.56     10745
# weighted avg       0.83      0.79      0.72     10745

# %% [markdown]
# # AdaBoostClassifier

# %%
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
pred=ad.predict(x_test)
ad_accu=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.8577943229409027
# [[7596  515]
#  [1013 1621]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      8111
#            1       0.76      0.62      0.68      2634
#
#     accuracy                           0.86     10745
#    macro avg       0.82      0.78      0.79     10745
# weighted avg       0.85      0.86      0.85     10745

# %% [markdown]
# # GaussianNB

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
pred=gnb.predict(x_test)
gnb_accu=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.7892042810609586
# [[7665  446]
#  [1819  815]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87      8111
#            1       0.65      0.31      0.42      2634
#
#     accuracy                           0.79     10745
#    macro avg       0.73      0.63      0.64     10745
# weighted avg       0.77      0.79      0.76     10745

# %% [markdown]
# # MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
pred=mnb.predict(x_test)
mnb_accu=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.7779432294090275
# [[7743  368]
#  [2018  616]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.87      8111
#            1       0.63      0.23      0.34      2634
#
#     accuracy                           0.78     10745
#    macro avg       0.71      0.59      0.60     10745
# weighted avg       0.75      0.78      0.74     10745

# %% [markdown]
# # LinearSVC

# %%
LSVC=LinearSVC()
LSVC.fit(x_train,y_train)
pred=LSVC.predict(x_test)
LSVC_accu=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.76379711493718
# [[8106    5]
#  [2533  101]]
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      8111
#            1       0.95      0.04      0.07      2634
#
#     accuracy                           0.76     10745
#    macro avg       0.86      0.52      0.47     10745
# weighted avg       0.81      0.76      0.67     10745

# %% [markdown]
# # DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
pred=dt.predict(x_test)
dt_accu=accuracy_score(y_test,pred)

print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.8078175895765473
# [[7021 1090]
#  [ 975 1659]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      8111
#            1       0.60      0.63      0.62      2634
#
#     accuracy                           0.81     10745
#    macro avg       0.74      0.75      0.74     10745
# weighted avg       0.81      0.81      0.81     10745

# %% [markdown]
# # GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
pred=gbc.predict(x_test)
gbc_accu=accuracy_score(y_test,pred)

print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.8586319218241042
# [[7664  447]
#  [1072 1562]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      8111
#            1       0.78      0.59      0.67      2634
#
#     accuracy                           0.86     10745
#    macro avg       0.83      0.77      0.79     10745
# weighted avg       0.85      0.86      0.85     10745

# %%
results = pd.DataFrame({
    'Model': ['SVC', 'KNN',  
              'Random Forest',  'Decision Tree','MultinomialNB','GaussianNB','AdaBoostClassifier',
              'LinearSVC','LogisticRegression','GradientBoostingClassifier'],
               
    
    'Score': [svc_accu, knn_accu, 
             rf_accu,  dt_accu, mnb_accu, gnb_accu, 
              ad_accu,LSVC_accu,lg_accu,gbc_accu]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                                Model
# Score
# 0.858632  GradientBoostingClassifier
# 0.857794          AdaBoostClassifier
# 0.853886               Random Forest
# 0.807818               Decision Tree
# 0.789204                  GaussianNB
# 0.787994                         SVC
# 0.784923                         KNN
# 0.784923          LogisticRegression
# 0.777943               MultinomialNB
# 0.763797                   LinearSVC

# %% [markdown]
# GradientBoostingClassifier is accuracy score ,precision ,recall and f1-score is good than other models,Hence  GradientBoostingClassifier
# is performing is good. GradientBoostingClassifier is best model for this dataset.

# %% [markdown]
# # cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(dt,x,y,cv=5).mean())
# Out:
# 0.8082923832923832

# %%
print(cross_val_score(rf,x,y,cv=5).mean())
# Out:
# 0.8564803439803439

# %%
print(cross_val_score(svc,x,y,cv=5).mean())
# Out:
# 0.7952088452088452

# %%
print(cross_val_score(ad,x,y,cv=5).mean())
# Out:
# 0.8588144963144962

# %%
print(cross_val_score(mnb,x,y,cv=5).mean())
# Out:
# 0.7826781326781327

# %%
print(cross_val_score(gnb,x,y,cv=5).mean())
# Out:
# 0.7952702702702703

# %%
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.7765663390663391

# %%
print(cross_val_score(lg,x,y,cv=5).mean())
# Out:
# 0.7925061425061426

# %%
print(cross_val_score(gbc,x,y,cv=5).mean())
# Out:
# 0.8640356265356266

# %%
print(cross_val_score(LSVC,x,y,cv=5).mean())
# Out:
# 0.6706388206388206

# %% [markdown]
# # AUC-ROC curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
#GradientBoostingClassifier
y_pred_prob=gbc.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([0.06586549, 0.02752115, 0.01543425, ..., 0.0076234 , 0.28152792,
#        0.02666805])

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , ..., 0.99790408, 0.99864382,
#        1.        ])

# %%
tpr
# Out:
# array([0.00000000e+00, 3.79650721e-04, 4.55580866e-03, ...,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00])

# %%
thresholds
# Out:
# array([1.99212116, 0.99212116, 0.98820642, ..., 0.00446514, 0.0044318 ,
#        0.00327505])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Decision tree classifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('GradientBoostingClassifier')
plt.show()
auc_score=roc_auc_score(y_test,gbc.predict(x_test))
auc_score
# Out:
# 0.768952041375048

# %% [markdown]
# # hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameter = {'max_depth' : np.arange(2,10),
              'criterion':['gini','entropy']}

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8}

# %%
GCV.best_score_
# Out:
# 0.8549163419665368

# %%
rfc=RandomForestClassifier(random_state=42)
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)

# %%
CV_rfc.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
CV_rfc.best_score_
# Out:
# 0.8577584231033694

# %%
ada=AdaBoostClassifier()
search_grid={'n_estimators':[500,1000,2000],
             'learning_rate':[.001,0.01,.1]}

# %%
search=GridSearchCV(estimator=ada,param_grid=search_grid,scoring='accuracy',n_jobs=1,cv=5)

# %%
search.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'n_estimators': [500, 1000, 2000]},
#              scoring='accuracy')

# %%
search.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 2000}

# %%
search.best_score_
# Out:
# 0.8654791154791155

# %%
grid_params={ 'n_neighbors':[3,5,11,19],
            'weights': ['uniform','distance'],
            'metric':['éuclidean','manhattan']}

# %%
gs=GridSearchCV(knn,grid_params,verbose=1,cv=3,n_jobs=-1)

# %%
gs_result=gs.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits

# %%
gs_result.best_score_
# Out:
# 0.7995874473982951

# %%
gs_result.best_estimator_
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=19)

# %%
gs_result.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 19, 'weights': 'uniform'}

# %% [markdown]
# # saving the model

# %%
import pickle
filename='Census Income.pkl'
pickle.dump(dt,open(filename,'wb'))

# %% [markdown]
# # conclusion

# %%
loaded_model=pickle.load(open('Census Income.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.8078175895765473

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred[:]],index=["predicted","original"])

# %%
conclusion
# Out:
#            0      1      2      3      4      5      6      7      8      \
# predicted      0      0      0      0      0      0      1      0      0
# original       0      0      0      0      0      0      1      0      0
#
#            9      ...  10735  10736  10737  10738  10739  10740  10741  10742  \
# predicted      0  ...      1      0      0      1      1      0      1      0
# original       0  ...      0      0      0      1      1      0      1      0
#
#            10743  10744
# predicted      0      0
# original       0      0
#
# [2 rows x 10745 columns]
