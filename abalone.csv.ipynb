# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("abalone.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# All 8 features and 1 column for specifying Rings.

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# we have float types,int types and object types of values which are independent variable and the Rings is target variable in this dataset.

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# we have 4177 rows and 9 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.isna()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# Their no null values in this dataset.

# %%
df["Rings"].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24], dtype=int64)

# %% [markdown]
# Rings ranges from 1 to 29.

# %%
df.Rings.value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: Rings, dtype: int64

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
sns.countplot(df['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %%
sns.distplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %% [markdown]
# skewness is not present.

# %%
sns.distplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %% [markdown]
# skewness is present.

# %%
sns.distplot(df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %% [markdown]
# skewness is present in this plot.

# %%
sns.distplot(df['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [markdown]
# skewness is not present in this plot.

# %%
plt.scatter(df["Length"],df["Height"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Length vs Height")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present.

# %%
plt.scatter(df["Whole weight"],df["Shucked weight"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Whole weight vs Shucked weight")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present.

# %%
plt.scatter(df["Diameter"],df["Height"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Diameter vs Height")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present in this plot.

# %%
plt.scatter(df["Viscera weight"],df["Shell weight"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Viscera weight vs Shell weight")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present.

# %% [markdown]
# # checking correlation

# %%
cor=df.corr()
cor
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
sns.pairplot(df,hue='Rings')

# %%
sns.heatmap(cor,annot=True,linewidth=0.5,linecolor='green')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Light shades are highly correlated.
# Rings is highly correlated with shell weight.

# %% [markdown]
# # Label encoder

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Sex"]=LE.fit_transform(df["Sex"])

# %%
df["Sex"].unique()
# Out:
# array([2, 0, 1])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
corr_matrix=df.corr()
corr_matrix["Rings"].sort_values(ascending=False)
# Out:
# Rings             1.000000
# Shell weight      0.627574
# Diameter          0.574660
# Height            0.557467
# Length            0.556720
# Whole weight      0.540390
# Viscera weight    0.503819
# Shucked weight    0.420884
# Sex              -0.034627
# Name: Rings, dtype: float64

# %% [markdown]
# Their are identify the corrlation of independent variable with target variable "Rings".

# %% [markdown]
# # outlier removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

new_df=df[(z<3).all(axis=1)]

# %%
new_df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
new_df.shape
# Out:
# (4027, 9)

# %%
df.shape
# Out:
# (4177, 9)

# %%
(150/4177)*100
# Out:
# 3.5910940866650707

# %% [markdown]
# # Skewness

# %%
x=df.drop("Rings",axis=1)
y=df["Rings"]

# %%
x.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
new_df=power_transform(x)

new_df=pd.DataFrame(new_df,columns=x.columns)

# %%
new_df.skew()
# Out:
# Sex              -0.176442
# Length           -0.066669
# Diameter         -0.065977
# Height           -0.115483
# Whole weight     -0.003980
# Shucked weight    0.027351
# Viscera weight    0.039780
# Shell weight      0.023390
# dtype: float64

# %% [markdown]
# skewness has been removed.

# %%
x.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# # scaling the data using Min-Max Scaler:

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the traning accuracy is:- {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is:- {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the traning accuracy is:- 0.5266943382158247
# At random state 0,the testing accuracy is:- 0.5300147524184924
#
#
# At random state 1,the traning accuracy is:- 0.53428007569936
# At random state 1,the testing accuracy is:- 0.4992317277874875
#
#
# At random state 2,the traning accuracy is:- 0.5262530536009958
# At random state 2,the testing accuracy is:- 0.5151729794207711
#
#
# At random state 3,the traning accuracy is:- 0.5331198013832301
# At random state 3,the testing accuracy is:- 0.5015582743334918
#
#
# At random state 4,the traning accuracy is:- 0.5382795526015923
# At random state 4,the testing accuracy is:- 0.4733064659073897
#
#
# At random state 5,the traning accuracy is:- 0.5388633829890347
# At random state 5,the testing accuracy is:- 0.48137865136508584
#
#
# At random state 6,the traning accuracy is:- 0.5179147252140498
# At random state 6,the testing accuracy is:- 0.5660674008870981
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.5706447870955237

# %% [markdown]
# # cross-validation of the model:

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv_score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv_score is 0.5045305294380884 and accuracy score for training is -0.5417788919465729 and accuracy for the testing is 0.5706447870955237
#
#
# At cross fold 3 the cv_score is 0.4862195244230116 and accuracy score for training is -0.5417788919465729 and accuracy for the testing is 0.5706447870955237
#
#
# At cross fold 4 the cv_score is 0.3696395533562046 and accuracy score for training is -0.5417788919465729 and accuracy for the testing is 0.5706447870955237
#
#
# At cross fold 5 the cv_score is 0.39803615577874024 and accuracy score for training is -0.5417788919465729 and accuracy for the testing is 0.5706447870955237
#
#
# At cross fold 6 the cv_score is 0.37431659890243846 and accuracy score for training is -0.5417788919465729 and accuracy for the testing is 0.5706447870955237
#
#
# At cross fold 7 the cv_score is 0.42794108868716346 and accuracy score for training is -0.5417788919465729 and accuracy for the testing is 0.5706447870955237
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predict charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# Best fit line is covering most of the datapoints which shows good fit of our model.

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from  sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
lss
# Out:
# -0.0005164540710893561

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.2090330540722421

# %% [markdown]
# # Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf= GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="log2")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print("R2 score:",rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print("cross_val_score:",rfc*100)
# Out:
# R2 score: 60.66494408937429
# cross_val_score: 45.32848340924323

# %% [markdown]
# #   We are getting model accuracy  score is 60.6 and cross validation score is 45.3% which shows our model is performing is good.

# %% [markdown]
# # saving the model

# %%
import pickle
filename="abalone.pkl"
pickle.dump(rf,open(filename,"wb"))
