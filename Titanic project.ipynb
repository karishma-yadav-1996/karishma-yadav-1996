# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# we have int type,float type and object types of values which are independent variable and the Embarked is our target variable in this dataset.

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# we have 891 rows and 12 columns in this dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Their are two unique values in df['survived'].

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# 0 column has 549 values.
# 1 column has 342 values.

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# There are 177 missing values in Age and 687 missing values in Cabin.

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
sns.countplot(df["Survived"]);

# %% [markdown]
# There is class imbulance issue exists.

# %%
sns.boxplot(df['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %% [markdown]
# Their are no outliers present.

# %%
sns.boxplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# In this plot outliers is present.

# %%
sns.boxplot(df['SibSp'])
# Out:
# <AxesSubplot:xlabel='SibSp'>

# %% [markdown]
# Their are outliers is present.

# %%
sns.boxplot(df['Parch'])
# Out:
# <AxesSubplot:xlabel='Parch'>

# %% [markdown]
# Outliers are present.

# %%
sns.boxplot(df['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# Their are outliers are present.

# %%
sns.boxplot(df['PassengerId'])
# Out:
# <AxesSubplot:xlabel='PassengerId'>

# %% [markdown]
# Their are no outliers present in this plot.

# %%
sns.distplot(df['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed.

# %%
sns.distplot(df['Survived'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed in this column.

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed in this column.

# %%
sns.distplot(df['PassengerId'])
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Density'>

# %% [markdown]
# Data is normaly distributed in this column.

# %%
sns.distplot(df['SibSp'])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed in this column.

# %%
sns.distplot(df['Parch'])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed in this column.

# %%
sns.distplot(df['Embarked'])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed in this column.

# %%
# set up a category plot
g=sns.catplot(x="Pclass",y="Survived",hue="Sex",data=df,kind="bar")
# show plot
plt.show()

# %% [markdown]
# above plot is shown how much male and female is survived in this dataset.

# %% [markdown]
# # Bivariate analysis

# %%
plt.scatter(df["Pclass"],df["Survived"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Pclass vs Survived")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present.

# %%
plt.scatter(df["Age"],df["Parch"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Age vs Parch")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present.

# %%
plt.scatter(df["SibSp"],df["Parch"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("SibSp vs Parch")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present.

# %%
sns.pairplot(df,hue="Survived")

# %% [markdown]
# We can also check the corelation between dependent and independent features using dataframe.corr() function.

# %% [markdown]
# # checking correlation

# %%
cor=df.corr()
cor
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=[10,6])
sns.heatmap(cor,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
#  the variable Pclass seems to be most correlated with Sibsp. So let's go ahead and perform classification using Pclass as our feature variable.

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Sex"]=LE.fit_transform(df["Sex"])

# %%
df["Sex"].unique()
# Out:
# array([1, 0])

# %%
df["Name"]=LE.fit_transform(df["Name"])

# %%
df["Name"].unique()
# Out:
# array([108, 190, 353, 272,  15, 554, 515, 624, 412, 576, 727,  95, 729,
#         28, 840, 359, 682, 867, 839, 512, 273,  80, 523, 765, 626,  44,
#        240, 260, 605, 813, 828, 776, 289, 856, 535, 372, 505, 134, 837,
#        589,   7, 827, 446, 456, 212, 697, 473, 604, 726,  38, 629, 594,
#        333, 246, 620, 873, 707, 595, 853, 299, 749, 385, 337, 755, 784,
#        560, 596, 185,  25, 440, 396, 300, 376, 161,  87, 546, 778, 563,
#        127, 223, 842, 737, 519, 141, 386,  52, 255, 764, 259, 149, 159,
#         31, 150, 209, 184, 740, 292, 308, 219, 422, 656, 658, 858, 405,
#        312, 542, 724, 559, 675, 552, 667, 882,  67, 417,  46, 645, 178,
#        826,  70,  24, 362, 551, 575, 848, 857, 588, 525, 499, 653, 234,
#        225, 165, 695, 851, 772, 685, 585, 271, 618, 282,  99, 597, 319,
#        116,  32, 586,  29, 254, 580, 121,  68, 643, 532, 889, 612, 866,
#        287, 181, 767, 716, 186, 847,  82, 129, 628, 293, 157, 760,  69,
# ...

# %%
df["Embarked"]=LE.fit_transform(df["Embarked"])

# %%
df["Embarked"].unique()
# Out:
# array([2, 0, 1, 3])

# %%
df["Ticket"]=LE.fit_transform(df["Ticket"])

# %%
df["Ticket"].unique()
# Out:
# array([523, 596, 669,  49, 472, 275,  85, 395, 344, 132, 616,  38, 535,
#        333, 413, 153, 480, 151, 301, 184, 139, 152, 278,  42, 329, 179,
#         95, 283, 362, 598, 586, 288, 549, 600,  43, 202, 514, 302, 186,
#        507,  53, 391, 634, 282, 617, 462,  76, 190, 377, 249, 522, 587,
#        239,  29,  94, 555, 215, 561, 566, 197,  32, 457, 337, 601, 189,
#        553, 623, 248, 270, 557, 621, 204,  80, 347, 355, 473, 158, 432,
#        304, 311, 280,  25, 637, 247, 676, 652, 297, 298, 341, 678, 548,
#        428, 475, 607, 612, 117, 150, 384, 361, 417, 505, 245, 354, 296,
#        254, 388, 469,   2, 193, 274, 491, 176, 666, 460, 585, 540, 219,
#        463, 541, 196, 318, 380, 640, 537, 111, 552, 630,  55, 504, 592,
#        203, 332, 668, 438, 118, 558, 405, 113, 147, 622,  36, 516, 538,
#        573, 595, 418, 654, 258, 568, 470, 559, 323, 265, 423,  28, 576,
#          5, 659,  90, 412, 488, 593, 169, 574, 629, 114, 271,  34, 459,
# ...

# %%
df=df.drop(["Cabin"],axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0   NaN      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Embarked
# 0     7.2500         2
# 1    71.2833         0
# ...

# %%
corr_matrix=df.corr()
corr_matrix["Survived"].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Name          -0.057343
# Age           -0.064910
# Embarked      -0.163517
# Ticket        -0.164549
# Pclass        -0.338481
# Sex           -0.543351
# Name: Survived, dtype: float64

# %% [markdown]
# Their are identify the corrlation of independent variable with target variable "Survived".

# %% [markdown]
# # Missing value treatment

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Remove the missing value.
# There is no missing values in this dataset.

# %% [markdown]
# # outlier removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

new_df=df[(z<5).all(axis=1)]

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0  28.0      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Embarked
# 0     7.2500         2
# 1    71.2833         0
# ...

# %%
new_df.shape
# Out:
# (875, 11)

# %%
df.shape
# Out:
# (891, 11)

# %%
(16/891)*100
# Out:
# 1.7957351290684627

# %% [markdown]
# outliers has been removed.

# %% [markdown]
# # Skewness

# %%
x=df.drop("Survived",axis=1)
y=df["Survived"]

# %%
x.skew()
# Out:
# PassengerId    0.000000
# Pclass        -0.630548
# Name           0.000000
# Sex           -0.618921
# Age            0.510245
# SibSp          3.695352
# Parch          2.749117
# Ticket         0.000246
# Fare           4.787317
# Embarked      -1.246689
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
new_df=power_transform(x)

new_df=pd.DataFrame(new_df,columns=x.columns)

# %%
new_df.skew()
# Out:
# PassengerId   -0.283201
# Pclass        -0.441438
# Name          -0.288132
# Sex           -0.618921
# Age            0.074644
# SibSp          0.808608
# Parch          1.228795
# Ticket        -0.299695
# Fare          -0.040329
# Embarked      -0.861651
# dtype: float64

# %% [markdown]
# skewness has been removed.

# %%
x.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# # Handling class imbalance problem by oversampling the minority class

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x_over,y_over=SM.fit_resample(x,y)

# %%
y_over.value_counts()
# Out:
# 1    549
# 0    549
# Name: Survived, dtype: int64

# %% [markdown]
# # Finding best random_state

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30, random_state=1)

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(x_train, y_train)

y_prediction = random_forest.predict(x_test)

random_forest.score(x_train, y_train)
acc_random_forest = round(random_forest.score(x_train, y_train) * 100, 2)

print(acc_random_forest)
# Out:
# 100.0

# %%
logreg = LogisticRegression()
logreg.fit(x_train, y_train)

y_pred = logreg.predict(x_test)

acc_log = round(logreg.score(x_train, y_train) * 100, 2)

print(acc_log)
# Out:
# 80.9

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test) 
acc_knn = round(knn.score(x_train, y_train) * 100, 2)
print(acc_knn)
# Out:
# 82.18

# %%
gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
y_pred = gaussian.predict(x_test)
acc_gaussian = round(gaussian.score(x_train, y_train) * 100, 2)
print(acc_gaussian)
# Out:
# 81.06

# %%
linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)

y_pred = linear_svc.predict(x_test)

acc_linear_svc = round(linear_svc.score(x_train, y_train) * 100, 2)

# %%
print(acc_linear_svc)
# Out:
# 68.7

# %%
decision_tree = DecisionTreeClassifier() 
decision_tree.fit(x_train, y_train)
y_pred = decision_tree.predict(x_test)
acc_decision_tree = round(decision_tree.score(x_train, y_train) * 100, 2)
print(acc_decision_tree)
# Out:
# 100.0

# %%
results = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Decision Tree'],
              
    'Score': [acc_linear_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian,  acc_decision_tree]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df.head(9)
# Out:
#                           Model
# Score
# 100.00            Random Forest
# 100.00            Decision Tree
# 82.18                       KNN
# 81.06               Naive Bayes
# 80.90       Logistic Regression
# 68.70   Support Vector Machines

# %% [markdown]
# # K-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
rf = RandomForestClassifier(n_estimators=100)
scores = cross_val_score(rf, x_train, y_train, cv=10, scoring = "accuracy")
print("Scores:", scores)
print("Mean:", scores.mean())
print("Standard Deviation:", scores.std())
# Out:
# Scores: [0.87301587 0.77777778 0.85714286 0.88709677 0.88709677 0.83870968
#  0.87096774 0.87096774 0.83870968 0.82258065]
# Mean: 0.8524065540194572
# Standard Deviation: 0.03221379003109987

# %%
random_forest = RandomForestClassifier(n_estimators=100, oob_score = True)
random_forest.fit(x_train, y_train)
y_prediction = random_forest.predict(x_test)

random_forest.score(x_train, y_train)

acc_random_forest = round(random_forest.score(x_train, y_train) * 100, 2)
print(round(acc_random_forest,2,), "%")
# Out:
# 100.0 %

# %%
print("oob score:", round(random_forest.oob_score_, 4)*100, "%")
# Out:
# oob score: 83.78999999999999 %

# %% [markdown]
# # AUC-ROC CURVE

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=logreg.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([0.84448331, 0.10796812, 0.62947088, 0.70276208, 0.82907908,
#        0.17761435, 0.1603113 , 0.63678357, 0.15260205, 0.47465043,
#        0.20653479, 0.52192668, 0.16288058, 0.1108755 , 0.61351157,
#        0.23908285, 0.10216864, 0.14412091, 0.09716332, 0.58900246,
#        0.12367844, 0.05217282, 0.85247676, 0.31099783, 0.43697157,
#        0.72018846, 0.71631596, 0.70276208, 0.70228801, 0.70010407,
#        0.67427865, 0.66767411, 0.65287053, 0.65198367, 0.64940089,
#        0.63713301, 0.5572921 , 0.55468483, 0.52192668, 0.51815162,
#        0.4775915 , 0.47580426, 0.47147594, 0.43697157, 0.38684444,
#        0.38521219, 0.36205798, 0.33723039, 0.32808325, 0.30824221,
#        0.27848524, 0.27608771, 0.27570203, 0.27137789, 0.25761507,
#        0.25462902, 0.24871484, 0.2447979 , 0.23873037, 0.23821281,
#        0.23600112, 0.2344759 , 0.22958648, 0.22768735, 0.22747463,
#        0.22244039, 0.2220972 , 0.2202319 , 0.21188673, 0.19058537,
#        0.19033805, 0.18605661, 0.18537584, 0.18460289, 0.18363428,
#        0.17761435, 0.17564343, 0.17485826, 0.17473164, 0.1734223 ,
# ...

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic Regression')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Logistic Regression')
plt.show()

# %%
auc_score=roc_auc_score(y_test,logreg.predict(x_test))

# %%
print(auc_score)
# Out:
# 0.7379084967320262

# %%
y_pred_prob=decision_tree.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Decision tree classifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Decision Tree Classifier')
plt.show()
auc_score=roc_auc_score(y_test,decision_tree.predict(x_test))
print("AUC-ROC SCORE ",auc_score)
# Out:
# AUC-ROC SCORE  0.7345836885478829

# %%
y_pred_prob=random_forest.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='random forest classifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Decision Tree Classifier')
plt.show()
auc_score=roc_auc_score(y_test,random_forest.predict(x_test))
print("AUC-ROC SCORE ",auc_score)
# Out:
# AUC-ROC SCORE  0.7640238704177322

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
predictions = cross_val_predict(random_forest, x_train, y_train, cv=3)
confusion_matrix(y_train, predictions)
# Out:
# array([[366,  30],
#        [ 77, 150]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score

print("Precision:", precision_score(y_train, predictions))
print("Recall:",recall_score(y_train, predictions))
# Out:
# Precision: 0.8333333333333334
# Recall: 0.6607929515418502

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'max_depth' : np.arange(2,10),
              'criterion':['gini','entropy']}
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3}

# %%
parameters={'n_neighbors':[4,5,6,7,8],
             'leaf_size':[1,3,5],
              'algorithm':['auto','kd_tree'],
               'n_jobs':[-1]}
model=GridSearchCV(knn,param_grid=parameters)
model.fit(x_train,y_train)
model.best_params_
# Out:
# {'algorithm': 'auto', 'leaf_size': 1, 'n_jobs': -1, 'n_neighbors': 4}

# %%
prediction=model.predict(x_test)

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.77      0.69       153
#            1       0.57      0.40      0.47       115
#
#     accuracy                           0.61       268
#    macro avg       0.60      0.59      0.58       268
# weighted avg       0.60      0.61      0.60       268

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

# %%
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

# %%
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV 2/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV 3/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV 4/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV 5/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 2/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 3/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# ...

# %%
print(grid.best_params_)
# Out:
# {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
print(grid.best_estimator_)
# Out:
# SVC(C=1, gamma=0.0001)

# %%
grid_predictions=grid.predict(x_test)

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.77      0.69       153
#            1       0.57      0.40      0.47       115
#
#     accuracy                           0.61       268
#    macro avg       0.60      0.59      0.58       268
# weighted avg       0.60      0.61      0.60       268

# %%
Final_mod=DecisionTreeClassifier(criterion='gini', max_depth=3)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
acc=accuracy_score(y_test,pred)

# %% [markdown]
# # saving the model

# %%
import joblib
joblib.dump(Final_mod, "FinalModel.pkl")
# Out:
# ['FinalModel.pkl']
