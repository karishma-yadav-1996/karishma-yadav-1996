# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("Final_Test.csv")
df1
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %%
df=pd.read_csv("Final_Train.csv3", sep='\t')

# %%
df
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
df1.shape
# Out:
# (1987, 6)

# %% [markdown]
# we have 1987 rows and 6 columns.

# %%
df.shape
# Out:
# (5961, 7)

# %% [markdown]
# we have 5961 rows and 7 columns.

# %%
df.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %% [markdown]
# we have object types and int types of values which are independent variable and the Fees is our target variable in this dataset.

# %%
df1.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# dtype: object

# %% [markdown]
# we have object types of values which are independent variable.

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %% [markdown]
# In this dataset 6 features and Fees target variable.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5961 entries, 0 to 5960
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       5961 non-null   object
#  1   Experience          5961 non-null   object
#  2   Rating              2659 non-null   object
#  3   Place               5936 non-null   object
#  4   Profile             5961 non-null   object
#  5   Miscellaneous_Info  3341 non-null   object
#  6   Fees                5961 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 326.1+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       1987 non-null   object
#  1   Experience          1987 non-null   object
#  2   Rating              897 non-null    object
#  3   Place               1981 non-null   object
#  4   Profile             1987 non-null   object
#  5   Miscellaneous_Info  1153 non-null   object
# dtypes: object(6)
# memory usage: 93.3+ KB

# %% [markdown]
# we have only object types of values which are independent variable.

# %%
df.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64

# %% [raw]
# we have some missing values in this dataset.
# Rating  (3302)
# Miscellaneous_Info   (2620)

# %%
df.describe()
# Out:
#               Fees
# count  5961.000000
# mean    307.944640
# std     190.920373
# min       5.000000
# 25%     150.000000
# 50%     300.000000
# 75%     500.000000
# max     950.000000

# %%
df["Fees"].unique()
# Out:
# array([100, 350, 300, 250, 200, 700, 500, 400, 150, 650, 600,  50, 800,
#        750, 450,  80,  60, 550, 900, 950, 430, 130, 630, 499, 260,  70,
#         10, 299, 230, 380,   5, 280,  40,  30, 180, 920, 125, 850,  20,
#        220], dtype=int64)

# %% [markdown]
# There are Fees ranges from 5 to 950.

# %%
df["Fees"].value_counts()
# Out:
# 100    1306
# 500     938
# 200     904
# 300     864
# 400     424
# 250     307
# 150     253
# 600     215
# 700     153
# 800     143
# 350     143
# 50       81
# 450      65
# 750      34
# 550      22
# 650      21
# 900      18
# 70       18
# 80       12
# 60       11
# 30        4
# 10        2
# 260       2
# 130       2
# 180       2
# 40        2
# 380       2
# 220       1
# 280       1
# 499       1
# 5         1
# 920       1
# 299       1
# 125       1
# 230       1
# 430       1
# 630       1
# 850       1
# 950       1
# 20        1
# Name: Fees, dtype: int64

# %% [markdown]
# In this dataset 100 column has most values concentrated.

# %% [markdown]
# # EDA

# %%
sns.countplot(df["Fees"])
# Out:
# <AxesSubplot:xlabel='Fees', ylabel='count'>

# %% [markdown]
# In this plot is highest values present in 100 column.

# %%
for col in ['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
       'Miscellaneous_Info',]:
    sns.countplot(df[col].dropna(),orient='v')
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Profile',y='Fees',data=df)
plt.title("Doctor Fees wrt Profile")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# As Delhi, Banglore, Hyderabad, Mumbai and Chennai are in list of Tier 1 city so, as usual the doctor consultation fees in these metripolean cities are very high as compared to Tier 2 and Tier 3 city.

# %%
for col in ['Qualification', 'Experience', 'Rating', 'Place', 'Profile', 'Fees']:
    sns.boxplot(df[col].dropna(),orient='v')
    plt.title(col)
    plt.show()

# %% [markdown]
# Only Rating column has outliers is present.Rest of the columns has no outliers present.

# %%
sns.distplot(df["Fees"])
# Out:
# <AxesSubplot:xlabel='Fees', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed.

# %% [markdown]
# # Bivariate analysis

# %%
plt.scatter(df["Fees"],df["Experience"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Comparision between Fees and Experience")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present in this plot.

# %%
plt.scatter(df["Fees"],df["Profile"],alpha=0.8,c=(0,0,0),edgecolors='g')
plt.title("Comparision between Fees and Profile")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# outliers are present in this plot.

# %% [markdown]
# # label encoder

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
df["Qualification"]=LE.fit_transform(df["Qualification"])
df["Qualification"].unique()
# Out:
# array([ 401,   73, 1135, ..., 1229,  349, 1273], dtype=int64)

# %%
df["Experience"]=LE.fit_transform(df["Experience"])
df["Experience"].unique()
# Out:
# array([16,  3, 63, 12, 62, 36,  1,  5, 15, 44, 61, 13, 10, 35, 24, 17,  7,
#         6,  2, 14, 31, 55, 29,  4,  9, 40, 34, 43, 26,  0, 19, 23, 47, 56,
#        18, 28, 27, 32, 25,  8, 20, 53, 33, 39, 38, 22, 30, 45, 21, 37, 49,
#        60, 11, 46, 41, 42, 48, 51, 57, 54, 52, 50, 59, 58], dtype=int64)

# %%
df["Rating"]=LE.fit_transform(df["Rating"])
df["Rating"].unique()
# Out:
# array([ 0, 49, 51, 50, 30, 46, 48, 45, 39, 41, 31, 44,  2, 29, 38, 47, 33,
#        40, 25, 37, 43, 34, 27, 36,  9, 42, 18, 12, 26, 19, 24, 17, 28,  1,
#         8, 22, 35,  4, 14, 23, 32, 13, 10, 20,  6,  3, 21, 15, 16,  5, 11,
#         7], dtype=int64)

# %%
df["Place"]=LE.fit_transform(df["Place"])
df["Place"].unique()
# Out:
# array([299, 866, 457,  68, 337, 610, 326,  33, 546,  39, 783, 735, 131,
#        287, 364, 699, 766, 619, 290, 228, 605, 824, 112, 772,  28, 586,
#        388, 811, 147,  67, 732,  95, 478, 249, 675, 533,  89, 682, 434,
#        246, 143, 627, 612,  72, 499,   1, 420, 196, 115, 849, 871, 357,
#        439, 562, 509, 579, 465, 110,  27, 240,   5, 617, 428, 304,  40,
#        403,  19, 647, 713, 541, 473, 676, 203, 280, 559, 496, 798, 483,
#        877,  30,  65, 313, 218, 425, 142, 482, 373, 759, 293, 214,  86,
#        757, 872, 235, 547, 140, 251, 595, 709, 859, 346, 208,  52, 528,
#         48,  35, 103, 806, 221, 215, 567, 782, 737, 316, 603,  60, 360,
#        391, 809, 447, 197, 874,  45,  71, 433, 843, 363,  26, 750,   8,
#        386, 405, 778, 170,  80, 270, 632, 736, 339, 588, 317, 774, 867,
#        860, 555, 101, 116, 580, 503, 402, 460, 154, 840,  16, 572,  14,
#        519, 348, 155, 397,  75, 308, 241, 207, 828, 201, 493, 875, 202,
# ...

# %%
df["Profile"]=LE.fit_transform(df["Profile"])
df["Profile"].unique()
# Out:
# array([5, 0, 3, 1, 4, 2], dtype=int64)

# %% [markdown]
# There are 5 columns is object types variable . Using Label encoder these 5 column is converting into int type.

# %%
df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Fees
# 0               401          16       0    299        5   100
# 1                73           3      49    866        0   350
# 2              1135          63      51    457        3   300
# 3               464           3      51     68        0   250
# 4                10          12       0    337        0   250
# ...             ...         ...     ...    ...      ...   ...
# 5956           1075          10      49     70        3   300
# 5957            596          26      51    541        4   100
# 5958            596          35      48    216        4   600
# 5959            943           6      41    850        4   100
# 5960            243           8       0    603        1   200
#
# [5961 rows x 6 columns]

# %%
sns.jointplot(data=df,x='Fees',y='Experience',kind='reg')

# %% [markdown]
# using jointplot to find the best line or curve that fits the plots.In this plot Fees and Experience are two variables in ploting.

# %%
sns.jointplot(data=df,x='Fees',y='Rating',kind='reg')

# %% [markdown]
# using jointplot to find the best line or curve that fits the plots.In this plot Fees and Rating are two variables in ploting.

# %%
sns.jointplot(data=df,x='Fees',y='Profile',kind='reg')

# %% [markdown]
# using jointplot to find the best line or curve that fits the plots.In this plot Fees and Profile are two variables in ploting.

# %%
plt.figure(figsize=(10,8))
ax = sns.lineplot(x='Experience',y='Fees',data=df)
ax.set_title("Experience wrt doctor Fees")
plt.show()

# %% [markdown]
# The median of experience in bin 4 & 5 is 27 and 31 years respectively. whereas in highest rating of 10th bin the median experience is 14 years.

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Rating',y='Fees',data=df,palette='magma')
plt.title("Rating Vs Doctor_Fees")
plt.show()

# %% [markdown]
# the Rating is interesting column, we have grouped the rating in 10 bins, eg: bin5 will be rating of 40-49%.

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Rating',y='Experience',data=df,palette='magma')
plt.show()

# %% [markdown]
# As, we can see that High rating does not relate to high fees charged(infact low fees can be reason of high rating) and where fees are charged so high, there rating is between 30-60%.

# %% [markdown]
# # checking correlation

# %%
cor=df.corr()
cor
# Out:
#                Qualification  Experience    Rating   Profile      Fees
# Qualification       1.000000    0.003325  0.006554  0.393123  0.263214
# Experience          0.003325    1.000000 -0.030392 -0.032711 -0.048529
# Rating              0.006554   -0.030392  1.000000  0.046574 -0.071205
# Profile             0.393123   -0.032711  0.046574  1.000000  0.145226
# Fees                0.263214   -0.048529 -0.071205  0.145226  1.000000

# %% [markdown]
# This column is checking correlation between different different columns.

# %%
plt.figure(figsize=[20,12])
sns.heatmap(cor,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# I am using seaborn heatmap to plot the correlated matrix and plot the corr value in the heatmap graph.
# In this plot profile and fees has very low correlation between the columns.

# %%
sns.pairplot(df,hue="Fees")

# %% [markdown]
# We can check the corelation between dependent and independent features using dataframe.corr() function. This plot pairwise relationships in a dataset.

# %% [markdown]
# # correlation matrix

# %%
corr_matrix=df.corr()
corr_matrix["Fees"].sort_values(ascending=False)
# Out:
# Fees             1.000000
# Qualification    0.263214
# Profile          0.145226
# Experience      -0.048529
# Rating          -0.071205
# Name: Fees, dtype: float64

# %% [markdown]
# I am finding the correlation value of each column. Their are identify the corrlation of independent variable with target variable "Fees".

# %%
sns.distplot(df["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed.

# %% [markdown]
# # Handling missing values:

# %%
df["Rating"]=df["Rating"].fillna(df["Rating"].mean())

# %%
df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Fees
# 0               401          16       0    299        5   100
# 1                73           3      49    866        0   350
# 2              1135          63      51    457        3   300
# 3               464           3      51     68        0   250
# 4                10          12       0    337        0   250
# ...             ...         ...     ...    ...      ...   ...
# 5956           1075          10      49     70        3   300
# 5957            596          26      51    541        4   100
# 5958            596          35      48    216        4   600
# 5959            943           6      41    850        4   100
# 5960            243           8       0    603        1   200
#
# [5961 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Qualification    0
# Experience       0
# Rating           0
# Place            0
# Profile          0
# Fees             0
# dtype: int64

# %% [markdown]
# # outlier removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

new_df=df[(z<3).all(axis=1)]

# %%
new_df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Fees
# 0               401          16       0    299        5   100
# 1                73           3      49    866        0   350
# 2              1135          63      51    457        3   300
# 3               464           3      51     68        0   250
# 4                10          12       0    337        0   250
# ...             ...         ...     ...    ...      ...   ...
# 5956           1075          10      49     70        3   300
# 5957            596          26      51    541        4   100
# 5958            596          35      48    216        4   600
# 5959            943           6      41    850        4   100
# 5960            243           8       0    603        1   200
#
# [5941 rows x 6 columns]

# %%
new_df.shape
# Out:
# (5941, 6)

# %%
df.shape
# Out:
# (5961, 6)

# %%
(20/5961)*100
# Out:
# 0.33551417547391377

# %% [markdown]
# outliers has been removed.

# %% [markdown]
# # skewness

# %%
x=df.drop("Fees",axis=1)
y=df["Fees"]

# %%
x.skew()
# Out:
# Qualification    0.239720
# Experience       0.823531
# Rating          -2.049082
# Place            0.116574
# Profile          0.108803
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
new_df=power_transform(x)

new_df=pd.DataFrame(new_df,columns=x.columns)

# %%
new_df.skew()
# Out:
# Qualification   -0.298616
# Experience      -0.066770
# Rating          -1.780552
# Place           -0.267023
# Profile         -0.139151
# dtype: float64

# %% [markdown]
# skewness has been removed.

# %%
x.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# In given plot shown has no outliers are present.

# %% [markdown]
# # standard scaler

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaledX=scaler.fit_transform(df)

# %%
scaledX
# Out:
# array([[-4.73305738e-01, -3.34882629e-01, -2.61246491e+00,
#         -4.54258410e-01,  1.54301587e+00, -1.08926083e+00],
#        [-1.26594438e+00, -9.55840219e-01,  3.79506009e-01,
#          1.72682972e+00, -1.47289258e+00,  2.20295441e-01],
#        [ 1.30046489e+00,  1.91011789e+00,  5.01627271e-01,
#          1.53522763e-01,  3.36652489e-01, -4.16158134e-02],
#        ...,
#        [-2.07239780e-03,  5.72670771e-01,  3.18445378e-01,
#         -7.73535862e-01,  9.39834180e-01,  1.52985171e+00],
#        [ 8.36481290e-01, -8.12542314e-01, -1.08979039e-01,
#          1.66528226e+00,  9.39834180e-01, -1.08926083e+00],
#        [-8.55125573e-01, -7.17010377e-01, -2.61246491e+00,
#          7.15143341e-01, -8.69710893e-01, -5.65438323e-01]])

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %% [markdown]
# # LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
r2_sc=r2_score(y_test,pred)
print("R2 score :",r2_sc*100)
# Out:
# R2 score : 7.108527046214219

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 152.08761079840332
# MSE: 34268.12606758223
# RMSE: 185.11652024490473

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)
r2_sc=r2_score(y_test,pred)
print("R2 score :",r2_sc*100)
# Out:
# R2 score : -53.42108419624401

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 172.39396479463537
# MSE: 56597.80050293378
# RMSE: 237.902922434622

# %% [markdown]
# # KNeighborsRegressor

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
r2_sc=r2_score(y_test,pred)
print("R2 score :",r2_sc*100)
# Out:
# R2 score : 0.34435733326221296

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 150.8601844090528
# MSE: 36763.46189438391
# RMSE: 191.7380032606575

# %% [markdown]
# # RandomForestRegressor

# %%
rdr = RandomForestRegressor()
rdr.fit(x_train,y_train)
pred=rdr.predict(x_test)
r2_sc=r2_score(y_test,pred)
print("R2 score :",r2_sc*100)
# Out:
# R2 score : 12.592687793563295

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 140.2633952021714
# MSE: 32244.99191017101
# RMSE: 179.56890574420453

# %% [markdown]
# # SVR

# %%
svr = SVR()
svr.fit(x_train,y_train)
pred=svr.predict(x_test)
r2_sc=r2_score(y_test,pred)
print("R2 score :",r2_sc*100)
# Out:
# R2 score : 4.0469878832906865

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 148.2292288018253
# MSE: 35397.54308143557
# RMSE: 188.1423479215553

# %%
data = pd.DataFrame({'Y Test':y_test , 'Pred':pred},columns=['Y Test','Pred'])
sns.lmplot(x='Y Test',y='Pred',data=data,palette='rainbow')
data.head()
# Out:
#       Y Test        Pred
# 355      500  215.081023
# 897      500  235.982573
# 2116     280  336.448908
# 3385     100  247.428123
# 2797     250  351.795105

# %% [markdown]
# Best fit line is covering most of the datapoints which shows good fit of our model.

# %% [markdown]
# # cross validation of the model

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# -0.6156321058023917

# %%
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# -0.0009683344646711278

# %%
print(cross_val_score(rdr,x,y,cv=5).mean())
# Out:
# 0.1305994974449646

# %%
print(cross_val_score(lr,x,y,cv=5).mean())
# Out:
# 0.08115956332296562

# %%
print(cross_val_score(svr,x,y,cv=5).mean())
# Out:
# 0.05003827877259963

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predict charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# Best fit line is covering most of the datapoints which shows good fit of our model.

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameter={'max_depth' : np.arange(2,10),
           'criterion' : ['mse', 'friedman_mse', 'mae', 'poisson']}
GCV=GridSearchCV(DecisionTreeRegressor(),parameter,cv=5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 4}

# %%
dtr=DecisionTreeRegressor(criterion="mae",max_depth=8)
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
pred_decision=dtr.predict(x_test)

dts=r2_score(y_test,pred_decision)
print("R2 score:",dts*100)

dtrscore=cross_val_score(dtr,x,y,cv=5)
dtc=dtrscore.mean()
print("cross_val_score:",dtc*100)
# Out:
# R2 score: 0.6564634618781429
# cross_val_score: 1.061260103333883

# %%
parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf= GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="log2")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print("R2 score:",rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print("cross_val_score:",rfc*100)
# Out:
# R2 score: 12.567381906679175
# cross_val_score: 15.183853285734292

# %%
parameters={'n_neighbors' : range(1,30)}
gridsearch=GridSearchCV(knn,parameters)
gridsearch.fit(x_train,y_train)
gridsearch.best_params_
# Out:
# {'n_neighbors': 29}

# %%
KNN= KNeighborsRegressor(n_neighbors=3)
KNN.fit(x_train,y_train)
pred=KNN.predict(x_test)
r2_sc=r2_score(y_test,pred)
print("R2 score:",r2_sc*100)

KNNscore=cross_val_score(KNN,x,y,cv=5)
KNNc=KNNscore.mean()
print("cross_val_score:",KNNc*100)
# Out:
# R2 score: -7.981028989398964
# cross_val_score: -8.438978478018774

# %% [markdown]
# Random Forest Regressor is accuracy score and cross val score is good than other models,Hence this model is performing is good.
# Random Forest Regressor is best model for this dataset.

# %% [markdown]
# # saving the model

# %%
import pickle
filename='DoctorConsultionFees.pkl'
pickle.dump(df,open(filename,'wb'))
